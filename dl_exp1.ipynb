# %% [markdown]
# <a href="https://colab.research.google.com/github/vidyaneela/basic-nn-model/blob/main/dl_exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
import gspread
from google.auth import default
import pandas as pd

# %%
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# %%
worksheet = gc.open('mydata1').sheet1
data = worksheet.get_all_values()

# %%
rows = worksheet.get_all_values()

# %%
df = pd.DataFrame(rows[1:], columns=rows[0])
df = df.astype({'output':'int'})
df.head()
# Out:
#   input  output
# 0     1       3
# 1     2       5
# 2     3       7
# 3     4       9
# 4     5      11

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x=df[['input']].values
y=df[['output']].values

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=33)

# %%
Scaler=MinMaxScaler()

# %%
Scaler.fit(x_train)
# Out:
# MinMaxScaler()

# %%
 X_train1=Scaler.transform(x_train)
 X_test1 = Scaler.transform(x_test)

# %%
X_train1
# Out:
# array([[0.16666667],
#        [1.        ],
#        [0.        ],
#        [0.72222222],
#        [0.5       ],
#        [0.61111111],
#        [0.83333333],
#        [0.66666667],
#        [0.27777778],
#        [0.11111111],
#        [0.44444444],
#        [0.05555556],
#        [0.33333333]])

# %%
ai_brain=Sequential([
    Dense(8,activation='relu'),
    Dense(10,activation='relu'),
    Dense(1)
    ])

# %%
ai_brain.compile(optimizer='rmsprop',loss='mse')

# %%
ai_brain.fit(X_train1,y_train,epochs = 4000)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 337/4000
# 1/1 [==============================] - 0s 8ms/step - loss: 402.3379
# Epoch 338/4000
# 1/1 [==============================] - 0s 5ms/step - loss: 401.6702
# Epoch 339/4000
# 1/1 [==============================] - 0s 5ms/step - loss: 401.0013
# Epoch 340/4000
# 1/1 [==============================] - 0s 8ms/step - loss: 400.3309
# Epoch 341/4000
# 1/1 [==============================] - 0s 5ms/step - loss: 399.6591
# Epoch 342/4000
# 1/1 [==============================] - 0s 5ms/step - loss: 398.9860
# Epoch 343/4000
# 1/1 [==============================] - 0s 5ms/step - loss: 398.3114
# Epoch 344/4000
# 1/1 [==============================] - 0s 5ms/step - loss: 397.6354
# Epoch 345/4000
# 1/1 [==============================] - 0s 8ms/step - loss: 396.9582
# Epoch 346/4000
# 1/1 [==============================] - 0s 5ms/step - loss: 396.2794
# Epoch 347/4000
# ...

# %%
loss_df = pd.DataFrame(ai_brain.history.history)

loss_df.plot()
# Out:
# <Axes: >

# %%
ai_brain.evaluate(X_test1,y_test)

X_n1 = [[40]]

X_n1_1 = Scaler.transform(X_n1)

ai_brain.predict(X_n1_1)
# Out:
# ...
# 1/1 [==============================] - 0s 17ms/step
# array([[80.0844]], dtype=float32)
